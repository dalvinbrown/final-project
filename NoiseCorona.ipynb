# %%
import pandas as pd
import requests

# %%
app_token = 'cgUgSuYxy726CZkXECjUzKkTu'

# %%
limit = '$limit=450000'
url = f'https://data.cityofnewyork.us/resource/erm2-nwe9.json?{limit}'
response = requests.get(url)

# %%
data = response.json()

# %%
pd.DataFrame(data)
# Out:
#        unique_key             created_date agency  \
# 0        46198038  2020-05-15T02:01:30.000   NYPD
# 1        46199075  2020-05-15T02:01:09.000   NYPD
# 2        46202091  2020-05-15T02:00:53.000   NYPD
# 3        46194846  2020-05-15T02:00:09.000  DOHMH
# 4        46202129  2020-05-15T01:58:47.000   NYPD
# ...           ...                      ...    ...
# 449995   45624249  2020-02-16T01:16:39.000   NYPD
# 449996   45624897  2020-02-16T01:16:09.000   NYPD
# 449997   45626538  2020-02-16T01:15:34.000    TLC
# 449998   45626113  2020-02-16T01:15:21.000   NYPD
# 449999   45622234  2020-02-16T01:15:13.000   NYPD
#
#                                     agency_name           complaint_type  \
# 0               New York City Police Department      Noise - Residential
# 1               New York City Police Department          Illegal Parking
# 2               New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
df = pd.DataFrame(data)

# %%
df['complaint_type'].unique()
# Out:
# array(['Noise - Residential', 'Illegal Parking',
#        'Noise - Street/Sidewalk', 'Rodent', 'Non-Emergency Police Matter',
#        'Noise - Vehicle', 'New Tree Request',
#        'Homeless Person Assistance', 'Indoor Air Quality',
#        'Blocked Driveway', 'Maintenance or Facility',
#        'Noise - Commercial', 'Smoking', 'Noise - Helicopter',
#        'Homeless Street Condition', 'Drug Activity', 'Curb Condition',
#        'Consumer Complaint', 'Drinking', 'Street Light Condition',
#        'Traffic', 'Street Condition', 'Illegal Animal Kept as Pet',
#        'Traffic Signal Condition', 'Sidewalk Condition', 'Lead',
#        'PAINT/PLASTER', 'UNSANITARY CONDITION', 'Noise', 'Damaged Tree',
#        'Abandoned Vehicle', 'X-Ray Machine/Equipment', 'PLUMBING',
#        'ELECTRIC', 'Air Quality', 'HEAT/HOT WATER', 'Sewer',
#        'Water System', 'GENERAL', 'DOOR/WINDOW',
#        'Bus Stop Shelter Complaint', 'Taxi Report', 'Water Conservation',
# ...

# %%
df['complaint_type'].value_counts()
# Out:
# Noise - Residential            74435
# HEAT/HOT WATER                 42857
# Non-Emergency Police Matter    39689
# Illegal Parking                31131
# Consumer Complaint             19465
#                                ...
# Litter Basket / Request            1
# Squeegee                           1
# Lifeguard                          1
# FHV Licensee Complaint             1
# Calorie Labeling                   1
# Name: complaint_type, Length: 161, dtype: int64

# %%
noise = df[df['complaint_type'] == 'Noise - Residential']

# %%
noise
# Out:
#        unique_key             created_date agency  \
# 0        46198038  2020-05-15T02:01:30.000   NYPD
# 7        46195997  2020-05-15T01:58:29.000   NYPD
# 8        46195189  2020-05-15T01:58:03.000   NYPD
# 11       46202332  2020-05-15T01:57:18.000   NYPD
# 13       46195221  2020-05-15T01:56:00.000   NYPD
# ...           ...                      ...    ...
# 449991   45621020  2020-02-16T01:17:28.000   NYPD
# 449993   45621038  2020-02-16T01:17:12.000   NYPD
# 449994   45621653  2020-02-16T01:17:06.000   NYPD
# 449996   45624897  2020-02-16T01:16:09.000   NYPD
# 449998   45626113  2020-02-16T01:15:21.000   NYPD
#
#                             agency_name       complaint_type  \
# 0       New York City Police Department  Noise - Residential
# 7       New York City Police Department  Noise - Residential
# 8       New York City Police Department  Noise - Residential
# 11      New York City Police Department  Noise - Residential
# ...

# %%
party = noise[noise['descriptor'] == 'Loud Music/Party']

# %%
party
# Out:
#        unique_key             created_date agency  \
# 0        46198038  2020-05-15T02:01:30.000   NYPD
# 7        46195997  2020-05-15T01:58:29.000   NYPD
# 11       46202332  2020-05-15T01:57:18.000   NYPD
